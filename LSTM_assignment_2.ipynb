# %% [markdown]
# <a href="https://colab.research.google.com/github/github-ashwin/Python/blob/main/LSTM_assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout
from keras.utils import to_categorical

# %%
from pathlib import Path

path =  "C:\\Users\\Asus\\Desktop\\ASAS\\2nd Semester\\Deep Learning\\blockchain_document.txt"

text = Path(path).read_text(encoding="utf-8").lower()

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts([text])
total_words = len(tokenizer.word_index) + 1

# %%
total_words
# Out:
# 208

# %%
input_sequences = []
for line in text.split('.'):
    token_list = tokenizer.texts_to_sequences([line])[0]
    print(token_list)
    for i in range(1, len(token_list)):
        n_gram_sequence = token_list[:i + 1]
        input_sequences.append(n_gram_sequence)
# Out:
# [50, 5, 11, 5, 6, 4, 51, 11, 12, 27, 52, 1, 28, 9, 13, 29, 30, 53, 3, 16]
# [54, 10, 55, 4, 5, 6, 4, 56, 9, 31, 12, 57, 58, 7, 4, 17, 32, 3, 59, 18, 60]
# [61, 62, 63, 19, 5, 64, 65, 4, 14, 2, 66, 33, 12, 67, 68, 69, 27, 70, 71, 72, 1, 73, 20, 74]
# [4, 5, 6, 75, 2, 21, 34, 76, 4, 77, 2, 13]
# [15, 21, 29, 78, 79, 80, 4, 22]
# [34, 23, 81, 4, 82, 83, 20, 3, 4, 84, 85, 2, 1, 86, 23]
# [87, 88, 89, 1, 90, 2, 91, 4, 23, 6, 92, 8, 1, 22, 24, 6, 93, 94, 8, 95, 10, 96, 97, 98, 35, 99, 21, 3, 100, 36, 37, 1, 101, 2, 1, 14]
# [102, 2, 1, 103, 104, 105, 2, 5, 6, 7, 38, 25, 106, 3, 107]
# [15, 9, 108, 109, 39, 5, 8, 40, 4, 17, 3, 41, 110, 2, 13, 111, 1, 112, 42, 113, 25, 114]
# [43, 1, 44, 2, 5, 115, 116, 117, 38]
# [7, 118, 22, 45, 5, 119, 32, 120, 2, 121, 37, 122, 8, 123, 124, 125, 3, 33, 126]
# [7, 127, 128, 129, 130, 131, 132, 16, 133, 134, 135, 136, 137]
# [5, 6, 138, 139, 140, 7, 141, 46, 26, 142, 19, 143, 144, 3, 9, 145, 45]
# ...

# %%
max_sequence_length = max(len(seq) for seq in input_sequences)
input_sequences = pad_sequences(input_sequences, maxlen=max_sequence_length, padding='pre')

# %%
X, y = input_sequences[:, :-1], input_sequences[:, -1]
y = to_categorical(y, num_classes=total_words)

# %%
model = Sequential()
model.add(Embedding(total_words, 100, input_length=max_sequence_length - 1))
model.add(LSTM(110))
model.add(Dense(total_words, activation='softmax'))
# Out:
# c:\Users\Asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\core\embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X, y, epochs=500, verbose=1)
# Out:
# Epoch 1/500
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.0189 - loss: 5.3349
# Epoch 2/500
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0637 - loss: 5.2766
# Epoch 3/500
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0426 - loss: 5.0350
# Epoch 4/500
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0358 - loss: 4.9797
# Epoch 5/500
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0458 - loss: 4.8309
# Epoch 6/500
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0720 - loss: 4.7984
# Epoch 7/500
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0783 - loss: 4.7585
# Epoch 8/500
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.0847 - loss: 4.7191
# Epoch 9/500
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.0587 - loss: 4.7207
# Epoch 10/500
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.1023 - loss: 4.5708
# Epoch 11/500
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0941 - loss: 4.5126
# ...

# %%
def predict_next_word(model, tokenizer, input_text):
    input_seq = tokenizer.texts_to_sequences([input_text])[0]
    input_seq = pad_sequences([input_seq], maxlen=max_sequence_length - 1, padding='pre')
    predicted = model.predict(input_seq, verbose=0)
    return tokenizer.index_word[np.argmax(predicted)]

# %%
input_text = "Blockchain is"
next_word = predict_next_word(model, tokenizer, input_text)
print(f"The next word is: {next_word}")
# Out:
# The next word is: also

# %%
def predict_next_words(model, tokenizer, input_text, num_words=5):
    for _ in range(num_words):
        sequence = tokenizer.texts_to_sequences([input_text])[0]
        sequence = pad_sequences([sequence], maxlen=max_sequence_length - 1, padding='pre')
        predicted = np.argmax(model.predict(sequence), axis=-1)[0]
        output_word = tokenizer.index_word.get(predicted, '')

        if output_word == '':
            break

        input_text += ' ' + output_word
    return input_text

# Example usage
input_text = "Block chain is used"
generated_text = predict_next_words(model, tokenizer, input_text, num_words=40)
print(f"Generated text: {generated_text}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# ...
